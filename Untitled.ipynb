# %%
from IPython.display import Image
Image("img/table1.png")

# %%
Image("img/table2.png")

# %%
import numpy as np
np.random.seed(0) #начальное значение для генератора рандомных чисел

x1 = np.random.randint(10, size=6)
x2 = np.random.randint(10, size=(3, 4))
x3 = np.random.randint(10, size=(3, 4, 5))

# %%
print("x3 ndim:", x3.ndim)
print("x3 shape:", x3.shape)
print("x3 size:", x3.size)
# Out:
# x3 ndim: 3
# x3 shape: (3, 4, 5)
# x3 size: 60

# %%
print("dtype:", x3.dtype)
# Out:
# dtype: int32

# %%
print("itemsize:", x3.itemsize, "bytes")
print("nbytes:", x3.nbytes, "bytes")
# Out:
# itemsize: 4 bytes
# nbytes: 240 bytes

# %%
print(x2)
# Out:
# [[3 5 2 4]
#  [7 6 8 8]
#  [1 6 7 7]]

# %%
x2_sub = x2[:2, :2]
print(x2_sub)
# Out:
# [[3 5]
#  [7 6]]

# %%
x2_sub[0, 0] = 99
print(x2_sub)
# Out:
# [[99  5]
#  [ 7  6]]

# %%
print(x2)
# Out:
# [[99  5  2  4]
#  [ 7  6  8  8]
#  [ 1  6  7  7]]

# %% [markdown]
# <h1>Срезы numpy массивов есть ПРЕДСТАВЛЕНИЯ, а НЕ КОПИИ</h1>

# %%
grid = np.arange(1, 10).reshape((3,3))
print(grid)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]

# %%
Image('img/newaxis.png')

# %%
x = np.array([1, 2, 3])
y = np.array([3, 2, 1])
np.concatenate([x,y])
# Out:
# array([1, 2, 3, 3, 2, 1])

# %%
z = np.array([99, 99, 99])
np.concatenate([x,y,z])
# Out:
# array([ 1,  2,  3,  3,  2,  1, 99, 99, 99])
